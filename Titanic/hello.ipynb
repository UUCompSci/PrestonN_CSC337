# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
data
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0     29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1      0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3     30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4     25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# ...     ...    ...    ...     ...       ...      ...      ...  ...    ...
# 1304  14.50      1      0    2665   14.4542      NaN        C  NaN  328.0
# 1305    NaN      1      0    2665   14.4542      NaN        C  NaN    NaN
# 1306  26.50      0      0    2656    7.2250      NaN        C  NaN  304.0
# 1307  27.00      0      0    2670    7.2250      NaN        C  NaN    NaN
# 1308  29.00      0      0  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest  relatives
# 0                        St Louis, MO          0
# 1     Montreal, PQ / Chesterville, ON          1
# 2     Montreal, PQ / Chesterville, ON          1
# 3     Montreal, PQ / Chesterville, ON          1
# 4     Montreal, PQ / Chesterville, ON          1
# ...                               ...        ...
# 1304                              NaN          1
# 1305                              NaN          1
# 1306                              NaN          0
# 1307                              NaN          0
# 1308                              NaN          0
#
# [1309 rows x 15 columns]

# %%
data.to_excel("titanic.xlsx",sheet_name="passengers", index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display
# %matplotlib inline

data = pd.read_csv('titanic3.csv')

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
datadict = pd.DataFrame(data.dtypes)
datadict
# Out:
#                  0
# pclass       int64
# survived     int64
# name        object
# sex         object
# age        float64
# sibsp        int64
# parch        int64
# ticket      object
# fare       float64
# cabin       object
# embarked    object
# boat        object
# body       float64
# home.dest   object

# %%
datadict['MissingVal'] = data.isnull().sum()
datadict
# Out:
#                  0  MissingVal
# pclass       int64           0
# survived     int64           0
# name        object           0
# sex         object           0
# age        float64         263
# sibsp        int64           0
# parch        int64           0
# ticket      object           0
# fare       float64           1
# cabin       object        1014
# embarked    object           2
# boat        object         823
# body       float64        1188
# home.dest   object         564

# %%
datadict['Count'] = data.count
datadict
# Out:
#                  0  MissingVal  \
# pclass       int64           0
# survived     int64           0
# name        object           0
# sex         object           0
# age        float64         263
# sibsp        int64           0
# parch        int64           0
# ticket      object           0
# fare       float64           1
# cabin       object        1014
# embarked    object           2
# boat        object         823
# body       float64        1188
# home.dest   object         564
#
#                                                        Count
# pclass     <bound method DataFrame.count of       pclass ...
# survived   <bound method DataFrame.count of       pclass ...
# name       <bound method DataFrame.count of       pclass ...
# sex        <bound method DataFrame.count of       pclass ...
# age        <bound method DataFrame.count of       pclass ...
# sibsp      <bound method DataFrame.count of       pclass ...
# parch      <bound method DataFrame.count of       pclass ...
# ticket     <bound method DataFrame.count of       pclass ...
# fare       <bound method DataFrame.count of       pclass ...
# cabin      <bound method DataFrame.count of       pclass ...
# embarked   <bound method DataFrame.count of       pclass ...
# boat       <bound method DataFrame.count of       pclass ...
# body       <bound method DataFrame.count of       pclass ...
# home.dest  <bound method DataFrame.count of       pclass ...
